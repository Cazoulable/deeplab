# %%
import glob
import io
import math
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd

from PIL import Image
from tqdm import tqdm

# %%
os.environ['CUDA_VISIBLE_DEVICES'] = "1"
import tensorflow as tf

if tf.test.gpu_device_name():
    print('GPU found')
else:
    print("No GPU found")
# Out:
# No GPU found

# %%
experiment_id = 1

# %%
EXPERIMENT_DIR = '../../experiments/v{}'.format(experiment_id) 

# If the repo / data is organize correctly this shoult exists
assert os.path.exists(EXPERIMENT_DIR)

# %%
checkpoint_iter = 1000
model_checkpoint = os.path.join(EXPERIMENT_DIR, 'model.ckpt-{}'.format(checkpoint_iter))

# %%
# os.listdir(EXPERIMENT_DIR)

# %%
# config = tf.ConfigProto(device_count = {'GPU': -1})

# %%
inference_graph = tf.Graph()
# with tf.Session(graph=inference_graph, config=config) as sess:
with tf.Session(graph=inference_graph) as sess:
    loader = tf.train.import_meta_graph(model_checkpoint + '.meta')
    loader.restore(sess, model_checkpoint)
# Out:
# INFO:tensorflow:Restoring parameters from ../../experiments/v1/model.ckpt-1000
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# ~/python/virtualenv/python3/lib/python3.7/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1333     try:
# -> 1334       return fn(*args)
#    1335     except errors.OpError as e:
#
# ~/python/virtualenv/python3/lib/python3.7/site-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1316       # Ensure any changes to the graph are reflected in the runtime.
# -> 1317       self._extend_graph()
#    1318       return self._call_tf_sessionrun(
#
# ~/python/virtualenv/python3/lib/python3.7/site-packages/tensorflow/python/client/session.py in _extend_graph(self)
#    1351     with self._graph._session_run_lock():  # pylint: disable=protected-access
# ...

# %%
# tf.reset_default_graph()
# saver = tf.train.Saver()

# with tf.Session() as tf:
#     saver.restore(sess, model_checkpoint)
#     print("Model restore")

# %%
# with tf.Session(graph=tf.Graph()) as session:
#     tf.saved_model.loader.load(sess, [])
